# %%
## TSNMF 
#https://github.com/valentina-s/time-series-nmf #no time series based input

# generate some data
from numpy.random import rand
import tsnmf

data = rand(100,1000)
    
# fit time series nmf to data
model = tsnmf.smoothNMF(n_components=5)
model.fit(data)
    
# outputs
model.W
model.H

# %%
##SeqNMF https://github.com/ContextLab/seqnmf?tab=readme-ov-file
from numpy.random import rand
import numpy as np
from seqnmf import seqnmf, plot, example_data

import matplotlib.pyplot as plt

# %%
len(np.unique(example_data))/len(example_data.flatten())
False in (np.unique(example_data)>=0)
# Out:
# False

# %%
plt.matshow(example_data, cmap=plt.cm.Blues)

# %%
#data = rand(10,100)

[W, H, cost, loadings, power] = seqnmf(example_data, K=20, L=100, Lambda=0.001, plot_it=True)

plot(W, H).show()

# %%
print(example_data.shape, W.shape, H.shape)
# Out:
# (75, 666) (75, 20, 100) (20, 666)

# %%
#convmf 
#Convoluntional mf https://github.com/nishiba/convmf

# %%
import os
import pandas as pd
import numpy as np

# %%
path = "G:/My Drive/2021/Bias/sumo_simulation/"
os.chdir(path)

#get obs data matrix
data_path_lst = []
for i in os.listdir():
    if len(i) == 12 and '.csv' in i:
        data_path_lst.append(i)
data_path_lst
# Out:
# ['20170404.csv',
#  '20170405.csv',
#  '20170411.csv',
#  '20170406.csv',
#  '20170419.csv',
#  '20170418.csv',
#  '20170413.csv',
#  '20170412.csv',
#  '20170427.csv',
#  '20170426.csv',
#  '20170420.csv',
#  '20170425.csv']

# %%
test_data = pd.read_csv(data_path_lst[0])
test_data = pd.concat([test_data, pd.read_csv(data_path_lst[1])])

# %%
7197/19564
# Out:
# 0.3678695563279493

# %%
#check data counts within two days
print('# of ids covered', len(np.unique(test_data.newid)))
obs_ct = test_data.groupby(by=['newid']).size().to_frame()
obs_ct.reset_index(inplace=True)
obs_ct.columns = ['newid', 'ct']
obs_ct.sort_values(by=['ct'], ascending=False)
#plt.hist(obs_ct.ct)
obs_ct.groupby(by=['ct']).size()
# Out:
# # of ids covered 19564
# ct
# 1      3211
# 2      1763
# 3      1199
# 4      1024
# 5       809
#        ...
# 482       1
# 498       1
# 532       1
# 579       1
# 624       1
# Length: 305, dtype: int64
